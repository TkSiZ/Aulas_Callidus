# %%
import numpy as np
import skfuzzy as sk 
import matplotlib.pyplot as plt

# %% [markdown]
# Função Triangular

# %%
x_qual = np.arange(0, 11, 0.1)

# %% [markdown]
# Criando uma função triangular com os pontos 1, 2, 9 em Y

# %%
qual_lo = sk.trimf(x_qual, [1, 2, 9])

# %%
plt.plot(x_qual, qual_lo)
plt.grid()

# %%
#Definindo o fuzzy Range da velocidade de 30 a 80
x = np.arange(30, 80, 0.1)
# Definindo a triangular mmbership funcitons
slow = sk.trimf(x, [30, 30, 50])
medium = sk.trimf(x, [30, 50, 70])
medium_fast = sk.trimf(x, [50, 60, 80])
full_speed = sk.trimf(x, [60, 80, 80])
#Plotting the Membership Functions Defined
plt.figure()
plt.plot(x, full_speed, 'b', linewidth=1.5, label='Full Speed')
plt.plot(x, medium_fast, 'k', linewidth=1.5, label='Medium Fast')
plt.plot(x, medium, 'm', linewidth=1.5, label='Medium Powered')
plt.plot(x, slow, 'r', linewidth=1.5, label='Slow')
plt.title('Penalty Kick Fuzzy')
plt.ylabel('Membership')
plt.xlabel("Speed (Miles Per Hour)")
plt.legend(loc='center right', bbox_to_anchor=(1.25, 0.5),
ncol=1, fancybox=True, shadow=True)

# %%
# Defining the Numpy array for tp Quality

# %%
x_equal = np.arange(0, 11, 0.1)
#Defining the numpy array for Trapezoidal membership
qual_lo = sk.trapmf(x_qual, [1, 2.5, 8.5, 10])

# %%
plt.plot(x_qual, qual_lo)
plt.grid()

# %%
#Defining the Fuzzy Range from a speed of 30 to 90
x = np.arange(30, 90, 0.1)
#Defining the trapezoidal membership functions
slow = sk.trapmf(x, [20, 30, 30, 50])
medium = sk.trapmf(x, [30, 50, 60, 70])
medium_fast = sk.trapmf(x, [50, 60, 70, 80])
full_speed = sk.trapmf(x, [60, 70, 100,100])
#Plotting the Membership Functions Defined
plt.figure()
plt.plot(x, full_speed, 'b', linewidth=1.5, label='Full Speed')
plt.plot(x, medium_fast, 'k', linewidth=1.5, label='Medium Fast')
plt.plot(x, medium, 'm', linewidth=1.5, label='Medium Powered')
plt.plot(x, slow, 'r', linewidth=1.5, label='Slow')
plt.title('Penalty Kick Fuzzy')
plt.ylabel('Membership')
plt.xlabel("Speed (Miles Per Hour)")
plt.legend(loc='center right', bbox_to_anchor=(1.25, 0.5),
ncol=1, fancybox=True, shadow=True)

# %%
# Defining the numpy array for tip quality 
x_qual  = np.arange(0, 11, 0.1)
qual_lo = sk.gaussmf(x_qual, np.mean(x_qual)
